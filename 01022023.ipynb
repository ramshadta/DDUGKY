# %% [markdown]
# # Pandas functions/methods

# %%
#library installation
import pandas as pd
import numpy as np
df=pd.read_excel("C:\\Users\\USER\\Desktop\\Ramshad\\data sets\\Employee Sample Data.xlsx")

# %%
#to display entire df
df
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %%
#to display first n raws
df.head(10)
# Out:
#      EEID        Full Name                 Job Title  Department  \
# 0  E02387      Emily Davis                Sr. Manger          IT
# 1  E04105    Theodore Dinh       Technical Architect          IT
# 2  E02572     Luna Sanders                  Director     Finance
# 3  E02832  Penelope Jordan  Computer Systems Manager          IT
# 4  E01639        Austin Vo               Sr. Analyst     Finance
# 5  E00644     Joshua Gupta    Account Representative       Sales
# 6  E01550      Ruby Barnes                   Manager          IT
# 7  E04332      Luke Martin                   Analyst     Finance
# 8  E04533    Easton Bailey                   Manager  Accounting
# 9  E03838  Madeline Walker               Sr. Analyst     Finance
#
#             Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0  Research & Development  Female      Black   55 2016-04-08         141604
# 1           Manufacturing    Male      Asian   59 1997-11-29          99975
# ...

# %%
#to display last n raws
df.tail(10)
# Out:
#        EEID          Full Name             Job Title       Department  \
# 990  E01578       Anthony Hong            Sr. Manger               IT
# 991  E03430        Leo Herrera  Sr. Business Partner  Human Resources
# 992  E03058      Robert Wright   Technical Architect               IT
# 993  E04762  Audrey Richardson              Director               IT
# 994  E01148     Scarlett Kumar       Systems Analyst               IT
# 995  E03094       Wesley Young           Sr. Analyst        Marketing
# 996  E01909       Lillian Khan               Analyst          Finance
# 997  E04398        Oliver Yang              Director        Marketing
# 998  E02521        Lily Nguyen           Sr. Analyst          Finance
# 999  E03545        Sofia Cheng        Vice President       Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 990  Research & Development    Male      Asian   37 2010-11-29         146961
# ...

# %%
#random selection of n raws
df.sample(10)
# Out:
#        EEID          Full Name               Job Title       Department  \
# 709  E00245      Lucas Daniels                 Manager            Sales
# 764  E00276  Alexander Jackson                 Manager  Human Resources
# 909  E02938    Jace Washington                 Manager       Accounting
# 191  E03560            Ayla Ng  Account Representative            Sales
# 436  E00344        Savannah He                Director               IT
# 189  E02489        Ethan Clark    Sr. Business Partner  Human Resources
# 363  E04571   Hadley Contreras                Director      Engineering
# 765  E00951         Everly Lin        Business Partner  Human Resources
# 626  E03578        Maverick Li              Analyst II            Sales
# 563  E03550          Stella Wu              Sr. Manger        Marketing
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 709               Corporate    Male      Black   42 2011-05-29         102440
# ...

# %%
#to know difference while repeating the sample()
df.sample(10)
# Out:
#        EEID        Full Name              Job Title       Department  \
# 314  E04029   Jayden Jimenez                Manager  Human Resources
# 521  E02468       Ella Huang         Vice President        Marketing
# 18   E04116     David Barnes               Director               IT
# 428  E04041      Clara Huynh         IT Coordinator               IT
# 1    E04105    Theodore Dinh    Technical Architect               IT
# 257  E00976    Zoe Rodriguez               Director  Human Resources
# 904  E00952     Leilani Thao               Director  Human Resources
# 200  E00697  Jonathan Chavez  System Administrator                IT
# 899  E00647      Emily Gupta           HRIS Analyst  Human Resources
# 586  E02856      Amelia Kaur    Operations Engineer      Engineering
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 314               Corporate    Male     Latino   46 2011-09-24         102167
# ...

# %%
#to display total number of raws and columns
df.shape
# Out:
# (1000, 14)

# %%
#to list column info
df.columns
# Out:
# Index(['EEID', 'Full Name', 'Job Title', 'Department', 'Business Unit',
#        'Gender', 'Ethnicity', 'Age', 'Hire Date', 'Annual Salary', 'Bonus %',
#        'Country', 'City', 'Exit Date'],
#       dtype='object')

# %%
#to know data type of columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   EEID           1000 non-null   object
#  1   Full Name      1000 non-null   object
#  2   Job Title      1000 non-null   object
#  3   Department     1000 non-null   object
#  4   Business Unit  1000 non-null   object
#  5   Gender         1000 non-null   object
#  6   Ethnicity      1000 non-null   object
#  7   Age            1000 non-null   int64
#  8   Hire Date      1000 non-null   datetime64[ns]
#  9   Annual Salary  1000 non-null   int64
#  10  Bonus %        1000 non-null   float64
#  11  Country        1000 non-null   object
#  12  City           1000 non-null   object
#  13  Exit Date      85 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int64(2), object(9)
# memory usage: 109.5+ KB

# %%
#to obtain descreptive statistics of entire data frame
df.describe()
# Out:
#                Age  Annual Salary      Bonus %
# count  1000.000000    1000.000000  1000.000000
# mean     44.382000  113217.365000     0.088660
# std      11.246981   53545.985644     0.117856
# min      25.000000   40063.000000     0.000000
# 25%      35.000000   71430.250000     0.000000
# 50%      45.000000   96557.000000     0.000000
# 75%      54.000000  150782.250000     0.150000
# max      65.000000  258498.000000     0.400000

# %%
#to count null values in df
df.isnull().sum()
# Out:
# EEID               0
# Full Name          0
# Job Title          0
# Department         0
# Business Unit      0
# Gender             0
# Ethnicity          0
# Age                0
# Hire Date          0
# Annual Salary      0
# Bonus %            0
# Country            0
# City               0
# Exit Date        915
# dtype: int64

# %%
#to count duplicated values in df
df.duplicated().sum()
# Out:
# 0

# %%
#to display columns within a range
df.loc[50:60]
# Out:
#       EEID             Full Name            Job Title       Department  \
# 50  E04917  Everleigh Washington         HRIS Analyst  Human Resources
# 51  E00415        Leilani Butler           Analyst II        Marketing
# 52  E02862          Peyton Huang           Sr. Manger               IT
# 53  E04207        John Contreras           Analyst II        Marketing
# 54  E02139              Rylee Yu             Director       Accounting
# 55  E01797           Piper Lewis       Field Engineer      Engineering
# 56  E01839      Stella Alexander  Automation Engineer      Engineering
# 57  E01633            Addison Do  Operations Engineer      Engineering
# 58  E01848          Zoey Jackson     Business Partner  Human Resources
# 59  E00716             John Chow           Sr. Manger        Marketing
# 60  E00699             Ava Ayala           Sr. Manger               IT
#
#              Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# ...

# %%
#to count categorical variables seperately
df.value_counts()
# Out:
# EEID    Full Name       Job Title              Department   Business Unit           Gender  Ethnicity  Age  Hire Date   Annual Salary  Bonus %  Country        City       Exit Date
# E00119  Jack Maldonado  Director               Engineering  Research & Development  Male    Latino     31   2020-08-26  189290         0.22     Brazil         Sao Paulo  2020-09-25    1
# E03131  Ezekiel Reed    Sr. Manger             IT           Manufacturing           Male    Caucasian  37   2014-02-25  128984         0.12     United States  Miami      2021-05-01    1
# E03579  Robert Zhang    Vice President         Marketing    Corporate               Male    Asian      45   2015-09-24  202680         0.32     United States  Phoenix    2022-08-17    1
# E03563  Ian Barnes      Operations Engineer    Engineering  Corporate               Male    Caucasian  47   2020-06-08  115765         0.00     United States  Miami      2021-02-02    1
# ...

# %%
#to count categorical variables seperately  in a perticular column
df.Gender.value_counts()
# Out:
# Female    518
# Male      482
# Name: Gender, dtype: int64

# %%
#to club diff columns and do agregation
df.groupby(by=["Age","Annual Salary"]).value_counts()
# Out:
# Age  Annual Salary  EEID    Full Name           Job Title               Department       Business Unit           Gender  Ethnicity  Hire Date   Bonus %  Country        City            Exit Date
# 25   41336          E04332  Luke Martin         Analyst                 Finance          Manufacturing           Male    Black      2020-05-16  0.00     United States  Miami           2021-05-20    1
#      142731         E01789  Charles Luu         Sr. Manger              Sales            Manufacturing           Male    Asian      2021-06-15  0.11     China          Shanghai        2022-06-03    1
#      168014         E01896  Adam Nelson         Director                Finance          Speciality Products     Male    Caucasian  2020-01-14  0.27     United States  Chicago         2021-07-27    1
# ...

# %%
##to club diff columns and do agregation
df.groupby(by=["Age","Annual Salary"]).size()
# Out:
# Age  Annual Salary
# 25   41336            1
#      41844            1
#      46845            1
#      47974            1
#      56565            1
#                      ..
# 65   127626           1
#      149417           1
#      153938           1
#      170221           1
#      175837           1
# Length: 1000, dtype: int64

# %%
#to sort the df
df.sort_values(by='Full Name')
# Out:
#        EEID        Full Name          Job Title       Department  \
# 982  E03247      Aaliyah Mai     Vice President               IT
# 738  E02818      Aaron Garza           Director            Sales
# 954  E02684  Aaron Maldonado         Analyst II          Finance
# 693  E01877    Abigail Garza            Analyst       Accounting
# 26   E04545    Abigail Mejia   Quality Engineer      Engineering
# ..      ...              ...                ...              ...
# 257  E00976    Zoe Rodriguez           Director  Human Resources
# 97   E04931       Zoe Romero  Network Architect               IT
# 488  E04817      Zoe Sanchez        Sr. Analyst       Accounting
# 948  E03718         Zoe Zhou            Manager          Finance
# 58   E01848     Zoey Jackson   Business Partner  Human Resources
#
#               Business Unit  Gender Ethnicity  Age  Hire Date  Annual Salary  \
# 982     Speciality Products  Female     Asian   57 2016-11-11         246589
# ...

# %%
#to sort in descending order
df.sort_values(by='Annual Salary',ascending=False)
# Out:
#        EEID     Full Name        Job Title  Department  \
# 989  E04354  Raelynn Rios   Vice President       Sales
# 232  E04742  Kinsley Vega   Vice President  Accounting
# 900  E02522  Silas Rivera   Vice President       Sales
# 549  E01371    Dominic Le   Vice President   Marketing
# 610  E04170  Grayson Chin   Vice President          IT
# ..      ...           ...              ...         ...
# 787  E02732    Alice Tran          Analyst   Marketing
# 182  E03719    Jack Brown          Analyst   Marketing
# 823  E00862   Levi Moreno  Systems Analyst          IT
# 782  E04109   Leah Bryant   IT Coordinator          IT
# 781  E03928    Miles Dang   IT Coordinator          IT
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 989           Manufacturing  Female     Latino   43 2016-08-21         258498
# 232               Corporate  Female     Latino   33 2020-12-16         258426
# ...
